# %%
f = open("sarinah.txt",'w')
f.write("Helloo")
f.close()

# %%
f = open("t2.txt",'w')
f.write("hello\n")
f.write("Welcome")
f.close()

# %%
f = open("t1.txt",'w')
for i in range(1,11):
    f.write(str(i) + "\n")
f.close()

# %%
f= open("sarinah.txt",'w')
f.writelines(["Hellooo, ", "I'm urr loveee!"])
f.close()

# %%
f= open("sarinah.txt",'w')
f.writelines(["Hellooo, ", "I'm urr loveee!"])
f.read()
f.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-16-7628429f559d> in <module>
#       1 f= open("sarinah.txt",'w')
#       2 f.writelines(["Hellooo, ", "I'm urr loveee!"])
# ----> 3 f.read()
#       4 f.close()
#
# UnsupportedOperation: not readable

# %%
f= open("sarinah.txt",'a')
f.writelines(["Hellooo, ", "I'm urr loveee!", "\n"])
f.write("Heelloo, I'm tryng to append my file!! \n")
f.close()

# %%
f= open("3.txt",'a')
f.writelines(["Hellooo, ", "I'm urr loveee!", "\n"])
f.write("Heelloo, I'm tryng to append my file!! \n")
f.close()

# %%
f= open("3.txt")
# by default read---
print(f.read())
f.close()
# Out:
# Hellooo, I'm urr loveee!
# Heelloo, I'm tryng to append my file!!

# %%
f= open("3.txt")
# by default read---
print(f.read())
print("--", f.read())
f.close()
# Out:
# Hellooo, I'm urr loveee!
# Heelloo, I'm tryng to append my file!!
# --

# %%
f= open("sarinah.txt",'r')
# by default read---
print(f.read(4))
print("--", f.read())
f.close()
# Out:
# Hell
# -- ooo, I'm urr loveee!Hellooo, I'm urr loveee!Heelloo, I'm tryng to append my file!!Hellooo, I'm urr loveee!Heelloo, I'm tryng to append my file!!Hellooo, I'm urr loveee!
# Heelloo, I'm tryng to append my file!!

# %%
f= open("sarinah.txt",'r')
# by default read---
print(f.read(4))
print("--", f.write('djifdso'))
f.close()
# Out:
# Hell
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-28-aa7c6ebdfcd4> in <module>
#       2 # by default read---
#       3 print(f.read(4))
# ----> 4 print("--", f.write('djifdso'))
#       5 f.close()
#
# UnsupportedOperation: not writable

# %%
f= open("t2.txt",'r')
# by default read---
print(f.readline())
print(f.readline())
f.close()
# Out:
# hello
#
# Welcome

# %%
f= open("t2.txt",'r')
# by default read---
print(f.readline() ,  end="")
print(f.readline())
f.close()
# Out:
# hello
# Welcome

# %%
f= open("t2.txt",'r')
# by default read---
# print(f.readline(5) ,  end="")
print(f.readline(5))
print(f.readline())
print(f.readline(5))
print(f.readline(100))
f.close()
# Out:
# hello
#
#
# Welco
# me

# %%
f= open("t2.txt",'r')
print(f.readlines())
f.close()
# Out:
# ['hello\n', 'Welcome']

# %%
f= open("t2.txt",'r')
print(f.readlines(5))
print(f.readlines(6))
f.close()
# Out:
# ['hello\n']
# ['Welcome']

# %%
f= open("t2.txt",'r+')
f.write("boyyyy")
print(f.readlines())
f.write("Sarinahhhhhhhhhhhhhhhhhhhhhhh :) loveeeeee uuu")
f.close()
# first read and then writee okayyy mann!
# Out:
# ['hello\n', 'WelcomeSarinahhhhhhhhhhhhhhhhhhhhhhh :) loveeeeee uuuSarinahhhSarinahhhhhhhhhhhhhhhhhhhhhhh :) loveeeeee uuu']

# %%
f = open("abc.txt", 'r+')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-72086bc9a0bc> in <module>
# ----> 1 f = open("abc.txt", 'r+')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc.txt'

# %%
f = open("abc.txt" , 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-7b1ab86e8414> in <module>
# ----> 1 f = open("abc.txt" , 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc.txt'

# %%
f = open("abc.txt" , 'w+')
# w+ and w me bhi file ka data udd jaaegaa!
#

# %%
f = open("abc.txt" , 'w+')
print(f.tell())
f.write("hiii, go to hell!")
print(f.readlines())
print(f.tell())
# Out:
# 0
# ['hiii, go to hell!']
# 34

# %%
f = open('sample.txt','w+')
print(f.tell())
f.write("welcone")
print(f.tell())
f.seek(0,1)
print(f.tell())
print(f.read())
f.close()
# Out:
# 0
# 7
# 7

# %%
f = open('sample.txt','a+')
print(f.tell())
f.write("welcone")
print(f.tell())
f.seek(0,1)
print(f.tell())
print(f.read())
f.close()
# Out:
# 7
# 14
# 14

# %%
f = open('sample.txt')
for i in f:
    print(i)
# Out:
# Hello , Good Morning!
#
# I love u diyaaaa

# %%
with open('sarinah.txt') as f:
    for i in f:
        print(i)
f.read()
# Out:
# Hellooo, I'm urr loveee!Hellooo, I'm urr loveee!Heelloo, I'm tryng to append my file!!Hellooo, I'm urr loveee!Heelloo, I'm tryng to append my file!!Hellooo, I'm urr loveee!
#
# Heelloo, I'm tryng to append my file!!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-12833144ab2c> in <module>
#       2     for i in f:
#       3         print(i)
# ----> 4 f.read()
#
# ValueError: I/O operation on closed file.

# %%
with open('sample.txt') as f:
    for i in f:
        print(f.name)
        print(f.mode)
        print(f.closed)
        print(f.readable())
        print(f.writable())
# Out:
# sample.txt
# r
# False
# True
# False
# sample.txt
# r
# False
# True
# False

# %%
name=input()
age=input()
f=open('customer.txt','w')
f.write(name)
f.write(age)
print(name+'\n')
print(age)
f.close()
# Out:
# sdfsd
# 34
# sdfsd
#
# 34

# %%
f = open("sample1.txt" , 'r+')
x = f.read()
f.seek(0)
f.write(x.upper())
f.close()

# %%
f =  open('friends.txt' , 'r+')
f=  f.readlines()[0::2]
for i in f:
    print(i)
# Out:
# Friends are crazy, Friends are naughty !
#
# Friends are like keygen, friends are like license key !

# %%
f = open("1.txt")

f1 = open("2.txt")

f3 = open("3.txt",'w+')
length =  max(len(f1.readlines()), len(f.readlines()))
f1.seek(0)
f.seek(0)

for i in range(length):
        f3.write(f.readline())
        f3.write(f1.readline())
f.close()
f1.close()
f3.close()
