# %%
try:
    f = open("vha.txt")
    print("hiii")
except:
    print("File nhi hai!")
# Out:
# File nhi hai!

# %%
try:
    f = open("vha.txt")
    print("hiii")
except Exception as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'vha.txt'

# %%
try:
    f = open("sarinah.txt",'w')
    print(hiii)
except Exception as e:
    print(e)
# Out:
# name 'hiii' is not defined

# %%
try:
    f = open("sarinah.txt")
    print(hiii)
except FileNotFoundError:
    print('File Not found!')
except NameError:
    print('Name Not found!')
except Exception as e:
        print(e)
# Out:
# Name Not found!

# %%
d = { 1 : "jsdhfj"}
try:
   x = 5/0
except KeyError:
    print('Key Not found!')
except Exception as e:
        print(e.with_traceback)#returns obj
print("B1 is best!")
# Out:
# <built-in method with_traceback of ZeroDivisionError object at 0x0000021C9E86B450>
# B1 is best!

# %%
try:
     f = open("sarinah.txt")
except:
    print("Sorryyy")
else:
    print(f.read())
finally:
    print("Everytime I come!")
# Out:
# Everytime I come!

# %%
def f():
    try:
        print(1)
    finally:
        print(2)
print(f())
# Out:
# 1
# 2
# None

# %%
def f():
    try:
        return (1)
    finally:
        return (2)
print(f())
# Out:
# 2

# %%
raise NameError("variable not defined")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-bacde8565434> in <module>
# ----> 1 raise NameError("variable not defined")
#
# NameError: variable not defined

# %%
name = input()
try:
    value = int(input())
    if value != 10:
        raise Exception('Only 10')
    print(value)
except  Exception as e:
    print(e)
# Out:
# 10
# 10
# 10

# %%
class Sarinah(Exception):
    def __init__(self, message):
        pass
balance = int(input())
withdraw = int(input("Withdraw: "))
try:
    if balance<0:
        raise Sarinah("Sarinah's balance can not be so low!!")
    if (balance - withdraw) <0:
        raise Exception("No negative!")
    print(balance-withdraw)
except Exception as e:
    print(e)
# Out:
# -100
# Withdraw: 3849
# Sarinah's balance can not be so low!!

# %%
l=[1,2]
print(type(l))
print(l.upper())
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-c0481a715b96> in <module>
#       1 l=[1,2]
#       2 print(type(l))
# ----> 3 print(l.upper())
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
class Atm:
    def __init__(self):
        self.pin=""
        self.balance = 5000
        print(id(self))
#         self.menu()
    def menu():
        choice=input('''
        1] Setpin
        2] Changepin
        3] Withdraw
        4] Deposit
        5] Check Balance
        6] Exit
        ''')
obj1 = Atm()
obj2 = Atm()
obj1.menu()
print(id(obj1), id(obj2))
L=[1]
L.append(2)
print(obj1.balance , obj1.pin )
# Out:
# 2321959388976
# 2321959389648
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-2af5b15b6e77> in <module>
#      16 obj1 = Atm()
#      17 obj2 = Atm()
# ---> 18 obj1.menu()
#      19 print(id(obj1), id(obj2))
#      20 L=[1]
#
# TypeError: menu() takes 0 positional arguments but 1 was given

# %%
class Atm:
    def __init__(self):
        self.pin=""
        self.balance = 5000
        print(id(self))
#         self.menu()
    def menu(self):#here, self is necessary
        choice=input('''
        1] Setpin
        2] Changepin
        3] Withdraw
        4] Deposit
        5] Check Balance
        6] Exit
        ''')
obj1 = Atm()
obj2 = Atm()
obj1.menu()
print(id(obj1), id(obj2))
L=[1]
L.append(2)
print(obj1.balance , obj1.pin )
# Out:
# 2321963746736
# 2321963747408
#
#         1] Setpin
#         2] Changepin
#         3] Withdraw
#         4] Deposit
#         5] Check Balance
#         6] Exit
#         4
# 2321963746736 2321963747408
# 5000

# %%
class Atm:
    def __init__(self, pin , balance):
        self.pin=pin
        self.balance = 5000
        print(id(self))
#         self.menu()
    def menu(self):
        choice=input('''
        1] Setpin
        2] Changepin
        3] Withdraw
        4] Deposit
        5] Check Balance
        6] Exit
        ''')
obj1 = Atm(23,1000)
obj2 = Atm(24,2000)
obj1.menu()
print(id(obj1), id(obj2))
L=[1]
L.append(2)
obj1.balance =10000
obj1.pin=10
print(obj1.balance , obj1.pin )
# Out:
# 2321967536832
# 2321967536496
#
#         1] Setpin
#         2] Changepin
#         3] Withdraw
#         4] Deposit
#         5] Check Balance
#         6] Exit
#         6
# 2321967536832 2321967536496
# 10000 10

# %%
class A:
    age = 10
    def __init__(self,name,age):
        self.name = name        
        print(self.name ,self.age)
    @staticmethod    
    def display():
        print(self.name)
        print(self.age)
o1 = A("Sarinah" , 23)
# Out:
# Sarinah 10
